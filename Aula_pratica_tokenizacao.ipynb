# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro4Albuquerque/Processamento-de-Linguagem-Natural/blob/main/Aula_pratica_tokenizacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup do Ambiente

# %% [markdown]
# ## Bibliotecas

# %%
# !pip install -q spacy nltk pandas
# !python -m spacy download pt_core_news_sm -q

import nltk
import spacy
import pandas as pd

nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)

nlp = spacy.load("pt_core_news_sm")

print("Ambiente configurado com sucesso.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 64.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Ambiente configurado com sucesso.

# %% [markdown]
# ## 1. Tokenzinação

# %% [markdown]
# ### 1.1 Tentativa com método nativo do Python (.split())

# %%
frase_ancora = "O banco aprovou o empréstimo ontem."

tokens_split = frase_ancora.split()
print("Tokens com .split():", tokens_split)

# Observe: o ponto final "." ficou colado na palavra "ontem."!
# Out:
# Tokens com .split(): ['O', 'banco', 'aprovou', 'o', 'empréstimo', 'ontem.']

# %% [markdown]
# ### 1.2 Tokenização com NLTK

# %%
from nltk.tokenize import word_tokenize

tokens_nltk = word_tokenize(frase_ancora, language='portuguese')
print("Tokens com NLTK:   ", tokens_nltk)
# Out:
# Tokens com NLTK:    ['O', 'banco', 'aprovou', 'o', 'empréstimo', 'ontem', '.']

# %% [markdown]
# ### 1.3 Tokenização com spaCy

# %%
doc_spacy = nlp(frase_ancora)
tokens_spacy = [token.text for token in doc_spacy]
print("Tokens com spaCy:  ", tokens_spacy)
# Out:
# Tokens com spaCy:   ['O', 'banco', 'aprovou', 'o', 'empréstimo', 'ontem', '.']

# %% [markdown]
# ### 1.4 Tokenização Desafio

# %%
frase_desafio = "O apartamento custa R$ 450.000,00 na Av. Paulista, nº 1000! Entrar em contato via lead@email.com."

print("--- NLTK ---")
print(word_tokenize(frase_desafio, language='portuguese'))

print("\n--- spaCy ---")
doc_desafio = nlp(frase_desafio)
print([token.text for token in doc_desafio])
# Out:
# --- NLTK ---
# ['O', 'apartamento', 'custa', 'R', '$', '450.000,00', 'na', 'Av.', 'Paulista', ',', 'nº', '1000', '!', 'Entrar', 'em', 'contato', 'via', 'lead', '@', 'email.com', '.']
#
# --- spaCy ---
# ['O', 'apartamento', 'custa', 'R$', '450.000,00', 'na', 'Av.', 'Paulista', ',', 'nº', '1000', '!', 'Entrar', 'em', 'contato', 'via', 'lead@email.com', '.']

# %% [markdown]
# ### Organização em tabela

# %%
doc = nlp("O apartamento custa R$ 450.000,00!")

dados_tokens = []
for token in doc:
    dados_tokens.append({
        "Token": token.text,
        "É Pontuação?": token.is_punct,
        "É Número?": token.is_digit or token.like_num,
        "É Espaço?": token.is_space
    })

df_tokens = pd.DataFrame(dados_tokens)
df_tokens
# Out:
#          Token  É Pontuação?  É Número?  É Espaço?
# 0            O         False      False      False
# 1  apartamento         False      False      False
# 2        custa         False      False      False
# 3           R$         False      False      False
# 4   450.000,00         False       True      False
# 5            !          True      False      False
